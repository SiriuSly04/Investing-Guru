# %%
pip install pandas_datareader

# %%
# !pip install --upgrade pandas_datareader

# %%
pip install yfinance

# %%
pip install git+https://github.com/pydata/pandas-datareader.git

# %%
pip install scikit-learn

# %%
# !pip install fbprophet

# %%
# !pip show pandas_datareader

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
import yfinance as yf

# %%
start_date = '2010-01-01'
end_date = '2022-04-01'

df = data.DataReader(name="RELIANCE.NS", data_source="yahoo", start=start_date, end=end_date)
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2010-01-04  540.427307  506.127411  540.427307  532.700500  35372156.0
# 2010-01-05  569.551208  527.697937  569.551208  530.323059   9872785.0
# 2010-01-06  542.111328  530.298279  534.879883  538.891846  10933743.0
# 2010-01-07  552.265076  533.938782  538.891846  547.832092  12090336.0
# 2010-01-08  551.670715  542.854309  548.797974  546.395691   6973331.0
#
#              Adj Close
# Date
# 2010-01-04  484.265961
# 2010-01-05  482.104767
# 2010-01-06  489.894470
# 2010-01-07  498.021820
# 2010-01-08  496.716034

# %%
df.tail()
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2022-03-28  2629.750000  2586.500000  2610.000000  2621.949951  4564891.0
# 2022-03-29  2638.000000  2607.399902  2638.000000  2622.550049  4007695.0
# 2022-03-30  2688.000000  2617.100098  2639.899902  2672.949951  7297028.0
# 2022-03-31  2669.699951  2628.600098  2664.949951  2634.750000  6102744.0
# 2022-04-01  2665.149902  2622.000000  2636.000000  2655.850098  3656408.0
#
#               Adj Close
# Date
# 2022-03-28  2621.949951
# 2022-03-29  2622.550049
# 2022-03-30  2672.949951
# 2022-03-31  2634.750000
# 2022-04-01  2655.850098

# %%
df = df.reset_index()
df.head()
# Out:
#         Date        High         Low        Open       Close      Volume  \
# 0 2010-01-04  540.427307  506.127411  540.427307  532.700500  35372156.0
# 1 2010-01-05  569.551208  527.697937  569.551208  530.323059   9872785.0
# 2 2010-01-06  542.111328  530.298279  534.879883  538.891846  10933743.0
# 3 2010-01-07  552.265076  533.938782  538.891846  547.832092  12090336.0
# 4 2010-01-08  551.670715  542.854309  548.797974  546.395691   6973331.0
#
#     Adj Close
# 0  484.265961
# 1  482.104767
# 2  489.894470
# 3  498.021820
# 4  496.716034

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
#          High         Low        Open       Close      Volume
# 0  540.427307  506.127411  540.427307  532.700500  35372156.0
# 1  569.551208  527.697937  569.551208  530.323059   9872785.0
# 2  542.111328  530.298279  534.879883  538.891846  10933743.0
# 3  552.265076  533.938782  538.891846  547.832092  12090336.0
# 4  551.670715  542.854309  548.797974  546.395691   6973331.0

# %%
plt.plot(df.Close)

# %%
df
# Out:
#              High          Low         Open        Close      Volume
# 0      540.427307   506.127411   540.427307   532.700500  35372156.0
# 1      569.551208   527.697937   569.551208   530.323059   9872785.0
# 2      542.111328   530.298279   534.879883   538.891846  10933743.0
# 3      552.265076   533.938782   538.891846   547.832092  12090336.0
# 4      551.670715   542.854309   548.797974   546.395691   6973331.0
# ...           ...          ...          ...          ...         ...
# 3018  2629.750000  2586.500000  2610.000000  2621.949951   4564891.0
# 3019  2638.000000  2607.399902  2638.000000  2622.550049   4007695.0
# 3020  2688.000000  2617.100098  2639.899902  2672.949951   7297028.0
# 3021  2669.699951  2628.600098  2664.949951  2634.750000   6102744.0
# 3022  2665.149902  2622.000000  2636.000000  2655.850098   3656408.0
#
# [3023 rows x 5 columns]

# %%
ma50 = df.Close.rolling(50).mean()

# %%
ma100 = df.Close.rolling(100).mean()
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma50, 'g')
plt.plot(ma100, 'r')
plt.plot(ma200, 'y')

# %%
from sklearn.preprocessing import MinMaxScalar
scalar = MinMaxScalar(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array

# %%
data_traing_array.shape

# %%
x_train = []
y_train = []

for i in range(100, data_traing_array.shape[0]):
  x_train.append(data_traing_array[i-100: i])
  y_train.append(data_traing_array[i, 0])

x_train
